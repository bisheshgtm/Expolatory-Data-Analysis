# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

pd.set_option("display.precision", 2)

# %% [markdown]
# Read the telecom_churn csv file.

# %%
data = pd.read_csv("telecom_churn.csv")

# %% [markdown]
# Show the first 10 rows of the dataset

# %%
data.head(10)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
# 7    MO             147        415                Yes              No
# 8    LA             117        408                 No              No
# 9    WV             141        415                Yes             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                   25.0              265.1              110
# 1                   26.0              161.6              123
# 2                    NaN              243.4              114
# 3                    NaN              299.4               71
# 4                    0.0              166.7              113
# 5                    0.0                NaN               98
# 6                   24.0              218.2               88
# 7                    0.0              157.0               79
# 8                    0.0              184.5               97
# 9                   37.0              258.6               84
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
# 5             37.98              220.6              101             18.75
# 6             37.09              348.5              108             29.62
# 7             26.69              103.1               94              8.76
# 8             31.37              351.6               80             29.89
# 9             43.96              222.0              111             18.87
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
# 5                203.9                118                9.18
# 6                212.6                118                9.57
# 7                211.8                 96                9.53
# 8                215.8                 90                9.71
# 9                326.4                 97               14.69
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
# 5                 6.3                 6               1.70
# 6                 7.5                 7               2.03
# 7                 7.1                 6               1.92
# 8                 8.7                 4               2.35
# 9                11.2                 5               3.02
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False
# 5                       0  False
# 6                       3  False
# 7                       0  False
# 8                       1  False
# 9                       0  False

# %% [markdown]
# Show the last 10 rows of the dataset

# %%
data.tail(10)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3323    IN             117        415                 No              No
# 3324    WV             159        415                 No              No
# 3325    OH              78        408                 No              No
# 3326    OH              96        415                 No              No
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3323                    0.0              118.4              126
# 3324                    0.0              169.8              114
# 3325                    0.0              193.4               99
# 3326                    0.0              106.6              128
# 3327                    0.0              134.7               98
# 3328                   36.0              156.2               77
# 3329                    0.0              231.1               57
# 3330                    0.0              180.8              109
# 3331                    0.0              213.8              105
# 3332                   25.0              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3323             20.13              249.3               97             21.19
# 3324             28.87              197.7              105             16.80
# 3325             32.88              116.9               88              9.94
# 3326             18.12              284.8               87             24.21
# 3327             22.90              189.7               68             16.12
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 3323                227.0                 56               10.22
# 3324                193.7                 82                8.72
# 3325                243.3                109               10.95
# 3326                178.9                 92                8.05
# 3327                221.4                128                9.96
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 3323                13.6                 3               3.67
# 3324                11.6                 4               3.13
# 3325                 9.3                 4               2.51
# 3326                14.9                 7               4.02
# 3327                11.8                 5               3.19
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 3323                       5   True
# 3324                       1  False
# 3325                       2  False
# 3326                       1  False
# 3327                       2  False
# 3328                       2  False
# 3329                       3  False
# 3330                       2  False
# 3331                       2  False
# 3332                       0  False

# %% [markdown]
# Show the dimensions (No. of rows and coulmns) of the dataset

# %%
data.shape
# Out:
# (3333, 20)

# %% [markdown]
# Print all the column names of the dataset

# %%
data.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# Print general information of the dataset like column, and datatype.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3328 non-null   float64
#  6   Total day minutes       3329 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
#  14  Total night charge      3333 non-null   float64
#  15  Total intl minutes      3333 non-null   float64
#  16  Total intl calls        3333 non-null   int64
#  17  Total intl charge       3333 non-null   float64
#  18  Customer service calls  3333 non-null   int64
#  19  Churn                   3333 non-null   bool
# dtypes: bool(1), float64(9), int64(7), object(3)
# memory usage: 498.1+ KB

# %% [markdown]
# After getting the datatype of every feature, you can see that there is a feature "**churn**" having Dtype as **bool**. Change that Dtype to **int64**.

# %%
data["Churn"] = data["Churn"].astype("int64")

# %% [markdown]
# Which method shows basic statistical characteristics of each numerical feature (`int64` and `float64` types): number of non-missing values, mean, standard deviation, range, median, 0.25 and 0.75 quartiles.

# %%
data.describe()
# Out:
#        Account length  Area code  Number vmail messages  Total day minutes  \
# count         3333.00    3333.00                3328.00            3329.00
# mean           101.06     437.18                   8.11             179.78
# std             39.82      42.37                  13.70              54.48
# min              1.00     408.00                   0.00               0.00
# 25%             74.00     408.00                   0.00             143.70
# 50%            101.00     415.00                   0.00             179.40
# 75%            127.00     510.00                  20.00             216.40
# max            243.00     510.00                  51.00             350.80
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count          3333.00           3333.00            3333.00          3333.00
# mean            100.44             30.56             200.98           100.11
# std              20.07              9.26              50.71            19.92
# min               0.00              0.00               0.00             0.00
# 25%              87.00             24.43             166.60            87.00
# 50%             101.00             30.50             201.40           100.00
# 75%             114.00             36.79             235.30           114.00
# max             165.00             59.64             363.70           170.00
#
#        Total eve charge  Total night minutes  Total night calls  \
# count           3333.00              3333.00            3333.00
# mean              17.08               200.87             100.11
# std                4.31                50.57              19.57
# min                0.00                23.20              33.00
# 25%               14.16               167.00              87.00
# 50%               17.12               201.20             100.00
# 75%               20.00               235.30             113.00
# max               30.91               395.00             175.00
#
#        Total night charge  Total intl minutes  Total intl calls  \
# count             3333.00             3333.00           3333.00
# mean                 9.04               10.24              4.48
# std                  2.28                2.79              2.46
# min                  1.04                0.00              0.00
# 25%                  7.52                8.50              3.00
# 50%                  9.05               10.30              4.00
# 75%                 10.59               12.10              6.00
# max                 17.77               20.00             20.00
#
#        Total intl charge  Customer service calls    Churn
# count            3333.00                 3333.00  3333.00
# mean                2.76                    1.56     0.14
# std                 0.75                    1.32     0.35
# min                 0.00                    0.00     0.00
# 25%                 2.30                    1.00     0.00
# 50%                 2.78                    1.00     0.00
# 75%                 3.27                    2.00     0.00
# max                 5.40                    9.00     1.00

# %% [markdown]
# Now show basic statistics on non-numerical features.

# %%
data.describe(include=["object", "bool"])
# Out:
#        State International plan Voice mail plan
# count   3333               3333            3333
# unique    51                  2               2
# top       WV                 No              No
# freq     106               3010            2411

# %% [markdown]
# How to show the basic statistics for categorical (type `object`) and boolean (type `bool`) features?

# %%
data.describe(include=["object", "bool"])
# Out:
#        State International plan Voice mail plan
# count   3333               3333            3333
# unique    51                  2               2
# top       WV                 No              No
# freq     106               3010            2411

# %% [markdown]
# <h2>Check for Missing Values</h2>
#
# How to check for missing values in each column?

# %%
data.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     5
# Total day minutes         4
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# <h2> Sorting</h2>
#
# How to sort a dataFrame using one of the variables (i.e columns) in ascending order and also in descending order?

# %%
data.sort_values(by="Total day charge", ascending=False).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 365     CO             154        415                 No              No
# 985     NY              64        415                Yes              No
# 2594    OH             115        510                Yes              No
# 156     OH              83        415                 No              No
# 605     MO             112        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 365                     0.0              350.8               75
# 985                     0.0              346.8               55
# 2594                    0.0              345.3               81
# 156                     0.0              337.4              120
# 605                     0.0              335.5               77
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 365              59.64              216.5               94             18.40
# 985              58.96              249.5               79             21.21
# 2594             58.70              203.4              106             17.29
# 156              57.36              227.4              116             19.33
# 605              57.04              212.5              109             18.06
#
#       Total night minutes  Total night calls  Total night charge  \
# 365                 253.9                100               11.43
# 985                 275.4                102               12.39
# 2594                217.5                107                9.79
# 156                 153.9                114                6.93
# 605                 265.0                132               11.93
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 365                 10.1                 9               2.73
# 985                 13.3                 9               3.59
# 2594                11.8                 8               3.19
# 156                 15.8                 7               4.27
# 605                 12.7                 8               3.43
#
#       Customer service calls  Churn
# 365                        1      1
# 985                        1      1
# 2594                       1      1
# 156                        0      1
# 605                        2      1

# %%
data.sort_values(by="Total day charge", ascending=True).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 1345    SD              98        415                 No              No
# 1397    VT             101        510                 No              No
# 2736    OK             127        510                 No             Yes
# 2753    OH             134        415                 No              No
# 1986    WI              70        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 1345                    0.0                0.0                0
# 1397                    0.0                0.0                0
# 2736                   27.0                2.6              113
# 2753                    0.0                7.8               86
# 1986                    0.0                7.9              100
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 1345              0.00              159.6              130             13.57
# 1397              0.00              192.1              119             16.33
# 2736              0.44              254.0              102             21.59
# 2753              1.33              171.4              100             14.57
# 1986              1.34              136.4               83             11.59
#
#       Total night minutes  Total night calls  Total night charge  \
# 1345                167.1                 88                7.52
# 1397                168.8                 95                7.60
# 2736                242.7                156               10.92
# 2753                186.5                 80                8.39
# 1986                156.6                 89                7.05
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 1345                 6.8                 1               1.84
# 1397                 7.2                 4               1.94
# 2736                 9.2                 5               2.48
# 2753                12.9                 2               3.48
# 1986                12.1                 1               3.27
#
#       Customer service calls  Churn
# 1345                       4      1
# 1397                       1      0
# 2736                       3      0
# 2753                       2      0
# 1986                       0      0

# %% [markdown]
# How to sort a dataFrame using multiple variables (i.e columns) in ascending order and also in descending order?

# %%
data.sort_values(by=["Total eve charge", "Total day charge"], ascending=True).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 2932    UT              97        415                 No              No
# 32      LA             172        408                 No              No
# 533     OK             125        415                 No             Yes
# 889     MN             103        415                 No              No
# 821     MN              80        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 2932                    0.0              209.2              134
# 32                      0.0              212.0              121
# 533                    36.0              201.3              117
# 889                     0.0              198.5              112
# 821                     0.0              105.8              110
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 2932             35.56                0.0                0              0.00
# 32               36.04               31.2              115              2.65
# 533              34.22               42.2               78              3.59
# 889              33.75               42.5               90              3.61
# 821              17.99               43.9               88              3.73
#
#       Total night minutes  Total night calls  Total night charge  \
# 2932                175.4                 94                7.89
# 32                  293.3                 78               13.20
# 533                 125.7                104                5.66
# 889                 179.2                124                8.06
# 821                 189.6                 87                8.53
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 2932                11.8                 6               3.19
# 32                  12.6                10               3.40
# 533                  5.4                 3               1.46
# 889                 12.4                 5               3.35
# 821                 13.1                 5               3.54
#
#       Customer service calls  Churn
# 2932                       1      0
# 32                         3      0
# 533                        1      0
# 889                        0      0
# 821                        0      0

# %%
data.sort_values(by=["Total eve charge", "Total day charge"], ascending= False).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 2732    NC             130        408                Yes              No
# 2331    IN              46        415                 No             Yes
# 2551    MD             102        415                 No              No
# 8       LA             117        408                 No              No
# 1601    AR              99        510                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 2732                    0.0              216.2              106
# 2331                   34.0              191.4              102
# 2551                    0.0              129.5               56
# 8                       0.0              184.5               97
# 1601                    0.0              242.3              102
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 2732             36.75              363.7               86             30.91
# 2331             32.54              361.8               96             30.75
# 2551             22.02              354.2              118             30.11
# 8                31.37              351.6               80             29.89
# 1601             41.19              350.9              102             29.83
#
#       Total night minutes  Total night calls  Total night charge  \
# 2732                126.7                123                5.70
# 2331                147.5                132                6.64
# 2551                145.5                 93                6.55
# 8                   215.8                 90                9.71
# 1601                163.1                 93                7.34
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 2732                16.9                 2               4.56
# 2331                 7.2                 2               1.94
# 2551                10.9                 3               2.94
# 8                    8.7                 4               2.35
# 1601                11.3                 3               3.05
#
#       Customer service calls  Churn
# 2732                       5      1
# 2331                       1      0
# 2551                       1      0
# 8                          1      0
# 1601                       0      1

# %% [markdown]
# <h2>Indexing and retrieving data</h2>
#
# What is the proportion of churned users in our dataframe?

# %%
data["Churn"].mean()
# Out:
# 0.14491449144914492

# %% [markdown]
# What are average values of numerical features for churned users?

# %%
data[data["Churn"]==1].describe()
# Out:
#        Account length  Area code  Number vmail messages  Total day minutes  \
# count          483.00     483.00                 483.00             483.00
# mean           102.66     437.82                   5.12             206.91
# std             39.47      42.79                  11.86              69.00
# min              1.00     408.00                   0.00               0.00
# 25%             76.00     408.00                   0.00             153.25
# 50%            103.00     415.00                   0.00             217.60
# 75%            127.00     510.00                   0.00             265.95
# max            225.00     510.00                  48.00             350.80
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count           483.00            483.00             483.00           483.00
# mean            101.34             35.18             212.41           100.56
# std              21.58             11.73              51.73            19.72
# min               0.00              0.00              70.90            48.00
# 25%              87.50             26.05             177.10            87.00
# 50%             103.00             36.99             211.30           101.00
# 75%             116.50             45.21             249.45           114.00
# max             165.00             59.64             363.70           168.00
#
#        Total eve charge  Total night minutes  Total night calls  \
# count            483.00               483.00             483.00
# mean              18.05               205.23             100.40
# std                4.40                47.13              19.95
# min                6.03                47.40              49.00
# 25%               15.05               171.25              85.00
# 50%               17.96               204.80             100.00
# 75%               21.20               239.85             115.00
# max               30.91               354.90             158.00
#
#        Total night charge  Total intl minutes  Total intl calls  \
# count              483.00              483.00            483.00
# mean                 9.24               10.70              4.16
# std                  2.12                2.79              2.55
# min                  2.13                2.00              1.00
# 25%                  7.71                8.80              2.00
# 50%                  9.22               10.60              4.00
# 75%                 10.79               12.80              5.00
# max                 15.97               20.00             20.00
#
#        Total intl charge  Customer service calls  Churn
# count             483.00                  483.00  483.0
# mean                2.89                    2.23    1.0
# std                 0.75                    1.85    0.0
# min                 0.54                    0.00    1.0
# 25%                 2.38                    1.00    1.0
# 50%                 2.86                    2.00    1.0
# 75%                 3.46                    4.00    1.0
# max                 5.40                    9.00    1.0

# %% [markdown]
# How much time (on average) do churned users spend on the phone during daytime?

# %%
data[data["Churn"] == 1]["Total day minutes"].mean()
# Out:
# 206.91407867494823

# %% [markdown]
# What is the maximum length of international calls among loyal users (`Churn == 0`) who do not have an international plan?

# %%
data[(data["Churn"] == 0) & (data["International plan"] == "No")]["Total intl minutes"].max()
# Out:
# 18.9

# %% [markdown]
# How to get the first or the last line of the data frame?

# %%
data.iloc[0]
# Out:
# State                        KS
# Account length              128
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages      25.0
# Total day minutes         265.1
# Total day calls             110
# Total day charge          45.07
# Total eve minutes         197.4
# Total eve calls              99
# Total eve charge          16.78
# Total night minutes       244.7
# Total night calls            91
# Total night charge        11.01
# Total intl minutes         10.0
# Total intl calls              3
# Total intl charge           2.7
# Customer service calls        1
# Churn                         0
# Name: 0, dtype: object

# %%
data.iloc[-1]
# Out:
# State                        TN
# Account length               74
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages      25.0
# Total day minutes         234.4
# Total day calls             113
# Total day charge          39.85
# Total eve minutes         265.9
# Total eve calls              82
# Total eve charge           22.6
# Total night minutes       241.4
# Total night calls            77
# Total night charge        10.86
# Total intl minutes         13.7
# Total intl calls              4
# Total intl charge           3.7
# Customer service calls        0
# Churn                         0
# Name: 3332, dtype: object

# %% [markdown]
# ### Applying Functions to Cells, Columns and Rows
#
# How can you apply a function to each column of a DataFrame to find the maximum value in each column?

# %%
data.apply(max)
# Out:
# State                        WY
# Account length              243
# Area code                   510
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages      51.0
# Total day minutes         350.8
# Total day calls             165
# Total day charge          59.64
# Total eve minutes         363.7
# Total eve calls             170
# Total eve charge          30.91
# Total night minutes       395.0
# Total night calls           175
# Total night charge        17.77
# Total intl minutes         20.0
# Total intl calls             20
# Total intl charge           5.4
# Customer service calls        9
# Churn                         1
# dtype: object

# %% [markdown]
# How can you filter rows in a DataFrame to select all states that start with the letter "W"?

# %%
data[data["State"].str.startswith("W")]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 9       WV             141        415                Yes             Yes
# 26      WY              57        408                 No             Yes
# 44      WI              64        510                 No              No
# 49      WY              97        415                 No             Yes
# 54      WY              87        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3278    WI              87        415                 No              No
# 3303    WI             114        415                 No             Yes
# 3319    WY              89        415                 No              No
# 3324    WV             159        415                 No              No
# 3329    WV              68        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 9                      37.0              258.6               84
# 26                     39.0              213.0              115
# 44                      0.0              154.0               67
# 49                     24.0              133.2              135
# 54                      0.0              151.0               83
# ...                     ...                ...              ...
# 3278                    0.0              238.0               97
# 3303                   26.0              137.1               88
# 3319                    0.0              115.4               99
# 3324                    0.0              169.8              114
# 3329                    0.0              231.1               57
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 9                43.96              222.0              111             18.87
# 26               36.21              191.1              112             16.24
# 44               26.18              225.8              118             19.19
# 49               22.64              217.2               58             18.46
# 54               25.67              219.7              116             18.67
# ...                ...                ...              ...               ...
# 3278             40.46              164.5               97             13.98
# 3303             23.31              155.7              125             13.23
# 3319             19.62              209.9              115             17.84
# 3324             28.87              197.7              105             16.80
# 3329             39.29              153.4               55             13.04
#
#       Total night minutes  Total night calls  Total night charge  \
# 9                   326.4                 97               14.69
# 26                  182.7                115                8.22
# 44                  265.3                 86               11.94
# 49                   70.6                 79                3.18
# 54                  203.9                127                9.18
# ...                   ...                ...                 ...
# 3278                282.5                132               12.71
# 3303                247.6                 94               11.14
# 3319                280.9                112               12.64
# 3324                193.7                 82                8.72
# 3329                191.3                123                8.61
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 9                   11.2                 5               3.02
# 26                   9.5                 3               2.57
# 44                   3.5                 3               0.95
# 49                  11.0                 3               2.97
# 54                   9.7                 3               2.62
# ...                  ...               ...                ...
# 3278                10.6                 6               2.86
# 3303                11.5                 7               3.11
# 3319                15.9                 6               4.29
# 3324                11.6                 4               3.13
# 3329                 9.6                 4               2.59
#
#       Customer service calls  Churn
# 9                          0      0
# 26                         0      0
# 44                         1      0
# 49                         1      0
# 54                         5      1
# ...                      ...    ...
# 3278                       2      0
# 3303                       2      0
# 3319                       3      0
# 3324                       1      0
# 3329                       3      0
#
# [327 rows x 20 columns]

# %% [markdown]
# How can you replace values in a DataFrame column, such as changing the values of "International plan" and "Voice mail plan" from "Yes" or "No" to True or False?

# %%
data["International plan"] = data["International plan"].map({"Yes": True, "No": False})
data["Voice mail plan"] = data["Voice mail plan"].map({"Yes": True, "No": False})

# %% [markdown]
# ### Grouping
#
# In general, grouping data in Pandas works as follows:

# %% [markdown]
# ```python
# df.groupby(by=grouping_columns)[columns_to_show].function()
# ```

# %% [markdown]
# 1. First, the `groupby` method divides the `grouping_columns` by their values. They become a new index in the resulting dataframe.
# 2. Then, columns of interest are selected (`columns_to_show`). If `columns_to_show` is not included, all non groupby clauses will be included.
# 3. Finally, one or several functions are applied to the obtained groups per selected columns.
#
# How can you group data by a specific column (e.g., "Churn") and then display statistical summaries (e.g., mean, standard deviation, etc.) for selected columns such as "Total day minutes," "Total eve minutes," and "Total night minutes"?

# %%
data.groupby("Churn")[["Total day minutes", "Total eve minutes", "Total night minutes"]].mean()
# Out:
#        Total day minutes  Total eve minutes  Total night minutes
# Churn
# 0                 175.18             199.04               200.13
# 1                 206.91             212.41               205.23

# %% [markdown]
# How can you group data by a specific column (e.g., "Churn") and then apply multiple aggregation functions (e.g., mean, standard deviation, min, max) to selected columns such as "Total day minutes," "Total eve minutes," and "Total night minutes"?

# %%
data.groupby("Churn").agg({
    "Total day minutes": ["mean", "std", "min", "max"],
    "Total eve minutes": ["mean", "std", "min", "max"],
    "Total night minutes": ["mean", "std", "min", "max"]
})
# Out:
#       Total day minutes                   Total eve minutes               \
#                    mean   std  min    max              mean    std   min
# Churn
# 0                175.18  50.2  0.0  315.6            199.04  50.29   0.0
# 1                206.91  69.0  0.0  350.8            212.41  51.73  70.9
#
#              Total night minutes
#          max                mean    std   min    max
# Churn
# 0      361.8              200.13  51.11  23.2  395.0
# 1      363.7              205.23  47.13  47.4  354.9

# %% [markdown]
# ### Summary tables
#
# How can you create a contingency table to observe the distribution of data across two variables, such as "Churn" and "International plan"?

# %%
pd.crosstab(data["Churn"], data["International plan"])
# Out:
# International plan  False  True
# Churn
# 0                    2664    186
# 1                     346    137

# %% [markdown]
# How can you create a contingency table to observe the distribution of data across two variables, such as "Churn" and "Voice mail plan"?

# %%
pd.crosstab(data["Churn"], data["Voice mail plan"])
# Out:
# Voice mail plan  False  True
# Churn
# 0                 2008    842
# 1                  403     80

# %% [markdown]
# How can you create a pivot table to calculate the average number of day, evening, and night calls grouped by "Area code"?

# %%
data.pivot_table(["Total day calls", "Total eve calls", "Total night calls"], ["Area code"], aggfunc="mean")
# Out:
#            Total day calls  Total eve calls  Total night calls
# Area code
# 408                 100.50            99.79              99.04
# 415                 100.58           100.50             100.40
# 510                 100.10            99.67             100.60

# %% [markdown]
# ### DataFrame transformations
#
# How can you calculate the total number of calls ("Total day calls", "Total eve calls", "Total night calls", and "Total intl calls") for all users and add this information as a new column named "Total calls" to the DataFrame?

# %%
data["Total calls"] = data["Total day calls"] + data["Total eve calls"] + data["Total night calls"] + data["Total intl calls"]

# %%
data
# Out:
#      State  Account length  Area code  International plan  Voice mail plan  \
# 0       KS             128        415               False             True
# 1       OH             107        415               False             True
# 2       NJ             137        415               False            False
# 3       OH              84        408                True            False
# 4       OK              75        415                True            False
# ...    ...             ...        ...                 ...              ...
# 3328    AZ             192        415               False             True
# 3329    WV              68        415               False            False
# 3330    RI              28        510               False            False
# 3331    CT             184        510                True            False
# 3332    TN              74        415               False             True
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                      25.0              265.1              110
# 1                      26.0              161.6              123
# 2                       NaN              243.4              114
# 3                       NaN              299.4               71
# 4                       0.0              166.7              113
# ...                     ...                ...              ...
# 3328                   36.0              156.2               77
# 3329                    0.0              231.1               57
# 3330                    0.0              180.8              109
# 3331                    0.0              213.8              105
# 3332                   25.0              234.4              113
#
#       Total day charge  Total eve minutes  ...  Total eve charge  \
# 0                45.07              197.4  ...             16.78
# 1                27.47              195.5  ...             16.62
# 2                41.38              121.2  ...             10.30
# 3                50.90               61.9  ...              5.26
# 4                28.34              148.3  ...             12.61
# ...                ...                ...  ...               ...
# 3328             26.55              215.5  ...             18.32
# 3329             39.29              153.4  ...             13.04
# 3330             30.74              288.8  ...             24.55
# 3331             36.35              159.6  ...             13.57
# 3332             39.85              265.9  ...             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn  Total calls
# 0                          1      0          303
# 1                          1      0          332
# 2                          0      0          333
# 3                          2      0          255
# 4                          3      0          359
# ...                      ...    ...          ...
# 3328                       2      0          292
# 3329                       3      0          239
# 3330                       2      0          264
# 3331                       2      0          336
# 3332                       0      0          276
#
# [3333 rows x 21 columns]

# %% [markdown]
# How can you delete specific columns or rows from a DataFrame?
# **Note:** It should alters the current DataFrame and should not return a new one.

# %%
data.drop(columns=["Total calls"], inplace=True)

# %%
data
# Out:
#      State  Account length  Area code  International plan  Voice mail plan  \
# 0       KS             128        415               False             True
# 1       OH             107        415               False             True
# 2       NJ             137        415               False            False
# 3       OH              84        408                True            False
# 4       OK              75        415                True            False
# ...    ...             ...        ...                 ...              ...
# 3328    AZ             192        415               False             True
# 3329    WV              68        415               False            False
# 3330    RI              28        510               False            False
# 3331    CT             184        510                True            False
# 3332    TN              74        415               False             True
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                      25.0              265.1              110
# 1                      26.0              161.6              123
# 2                       NaN              243.4              114
# 3                       NaN              299.4               71
# 4                       0.0              166.7              113
# ...                     ...                ...              ...
# 3328                   36.0              156.2               77
# 3329                    0.0              231.1               57
# 3330                    0.0              180.8              109
# 3331                    0.0              213.8              105
# 3332                   25.0              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# ...                ...                ...              ...               ...
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                          1      0
# 1                          1      0
# 2                          0      0
# 3                          2      0
# 4                          3      0
# ...                      ...    ...
# 3328                       2      0
# 3329                       3      0
# 3330                       2      0
# 3331                       2      0
# 3332                       0      0
#
# [3333 rows x 20 columns]

# %%
data.drop(index=[5], inplace=True)

# %%
data
# Out:
#      State  Account length  Area code  International plan  Voice mail plan  \
# 0       KS             128        415               False             True
# 1       OH             107        415               False             True
# 2       NJ             137        415               False            False
# 3       OH              84        408                True            False
# 4       OK              75        415                True            False
# ...    ...             ...        ...                 ...              ...
# 3328    AZ             192        415               False             True
# 3329    WV              68        415               False            False
# 3330    RI              28        510               False            False
# 3331    CT             184        510                True            False
# 3332    TN              74        415               False             True
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                      25.0              265.1              110
# 1                      26.0              161.6              123
# 2                       NaN              243.4              114
# 3                       NaN              299.4               71
# 4                       0.0              166.7              113
# ...                     ...                ...              ...
# 3328                   36.0              156.2               77
# 3329                    0.0              231.1               57
# 3330                    0.0              180.8              109
# 3331                    0.0              213.8              105
# 3332                   25.0              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# ...                ...                ...              ...               ...
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                          1      0
# 1                          1      0
# 2                          0      0
# 3                          2      0
# 4                          3      0
# ...                      ...    ...
# 3328                       2      0
# 3329                       3      0
# 3330                       2      0
# 3331                       2      0
# 3332                       0      0
#
# [3332 rows x 20 columns]

# %% [markdown]
# <h1> Visualizing the Data</h1>
#
# We'll do this using visual analysis with `matplotlib` and `Seaborn`.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Graphics in retina format are more sharp and legible
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# How can you create a count plot to visualize the distribution of the "International plan" variable, with separate bars for each "Churn" category,

# %%
sns.countplot(x="International plan", hue="Churn", data=data)
plt.show()

# %% [markdown]
# <h2> Univariate visualization</h2>
#
# *Univariate* analysis looks at one feature at a time. When we analyze a feature independently, we are usually mostly interested in the *distribution of its values* and ignore other features in the dataset.
#
# Create histograms to visualize the distribution of values for the features "Total day minutes" and "Total intl calls"?

# %%
data["Total day minutes"].hist()
plt.title("Total Day Minutes Distribution")
plt.xlabel("Total day minutes")
plt.ylabel("Frequency")
plt.show()

data["Total intl calls"].hist()
plt.title("Total Intl Calls Distribution")
plt.xlabel("Total intl calls")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Create density plots to visualize the distribution of values for the features "Total day minutes" and "Total intl calls"?

# %%
data["Total day minutes"].plot(kind="density")
plt.title("Total Day Minutes Density Plot")
plt.xlabel("Total day minutes")
plt.show()

data["Total intl calls"].plot(kind="density")
plt.title("Total Intl Calls Density Plot")
plt.xlabel("Total intl calls")
plt.show()

# %% [markdown]
# Create a box plot to visualize the distribution of the "Total intl calls" feature

# %%
sns.boxplot(y="Total intl calls", data=data)
plt.title("Total Intl Calls Box Plot")
plt.show()

# %% [markdown]
# Make a comparison between a box plot and a violin plot for visualizing the distribution of the "Total intl calls" feature.

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.boxplot(y="Total intl calls", data=data)
plt.title("Total Intl Calls Box Plot")

plt.subplot(1, 2, 2)
sns.violinplot(y="Total intl calls", data=data)
plt.title("Total Intl Calls Violin Plot")
plt.show()

# %% [markdown]
# <h2>Multivariate visualization</h2>
#
# Create a correlation matrix to visualize the relationships among numerical variables in a DataFrame, and display it using a heatmap?

# %%
corr_matrix = data.drop(["State", "International plan", "Voice mail plan", "Area code"], axis=1).corr()

sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix Heatmap")
plt.gcf().set_size_inches(10, 10)
plt.show()

# %% [markdown]
# ##### Scatter plot
#
# Create a scatter plot to visualize the relationship between two numerical variables, such as "Total day minutes" and "Total night minutes,"?

# %%
plt.scatter(data["Total day minutes"], data["Total night minutes"])
plt.title("Scatter Plot of Total Day Minutes vs Total Night Minutes")
plt.xlabel("Total day minutes")
plt.ylabel("Total night minutes")
plt.show()

# %% [markdown]
# Create a scatter plot with different colors for the "Churn" categories to visualize the relationship between "Total day minutes" and "Total night minutes"

# %%
sns.scatterplot(x="Total day minutes", y="Total night minutes", hue="Churn", data=data)
plt.title("Scatter Plot of Total Day Minutes vs Total Night Minutes with Churn")
plt.show()

# %% [markdown]
# Create a count plot to visualize the distribution of the "Customer service calls" variable, with different colors representing the "Churn" categories.

# %%
sns.countplot(x="Customer service calls", hue="Churn", data=data)
plt.title("Customer Service Calls Distribution")
plt.show()

# %% [markdown]
# <h1>Data Transformation</h1>

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Delete specific columns ( "Churn", "State" ) from a DataFrame, convert binary categorical values ("Yes"/"No") into numerical values

# %%
data.drop(columns=["Churn", "State"], inplace=True)
data["International plan"] = data["International plan"].map({"Yes": 1, "No": 0})
data["Voice mail plan"] = data["Voice mail plan"].map({"Yes": 1, "No": 0})

# %% [markdown]
# Now normalize the feature data by subtracting the mean and dividing by the standard deviation, and then convert the scaled data into a DataFrame

# %%
data = pd.read_csv("telecom_churn.csv")
data.fillna(0, inplace=True)
data.drop(columns=["State"], inplace=True)
data["International plan"] = data["International plan"].map({"Yes": 1, "No": 0})
data["Voice mail plan"] = data["Voice mail plan"].map({"Yes": 1, "No": 0})
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)
scaled_df = pd.DataFrame(scaled_data, columns=data.columns)

# %% [markdown]
# <h1>Splitting a Dataset into Train & Test Set</h1>
#
# How can you split a dataset into training and testing sets, with 25% of the data reserved for testing?

# %%
from sklearn.model_selection import train_test_split


X = scaled_df
y = pd.read_csv("telecom_churn.csv")["Churn"].map({"TRUE": 1, "FALSE": 0})

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=43)

# %% [markdown]
# <h1>Classification using Machine Learning</h1>

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# Train a Decision Tree classifier on the training data and make predictions on the test data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

dataSet = pd.read_csv("telecom_churn.csv")
dataSet['International plan'] = dataSet['International plan'].map({'Yes': '1', 'No': '0'})
dataSet['Voice mail plan'] = dataSet['Voice mail plan'].map({'Yes': '1', 'No': '0'})
train_index = int(dataSet.shape[0] * 0.75)
print(train_index)
X_train = dataSet.drop(['Churn','State'], axis=1).iloc[:train_index, :]
X_train = X_train
print(X_train.shape)
y_train = dataSet['Churn'].iloc[:train_index]

X_test = dataSet.drop(['Churn','State'], axis=1).iloc[train_index:, :]
y_test = dataSet['Churn'].iloc[train_index:]

tree = DecisionTreeClassifier(random_state=17)
tree.fit(X_train, y_train)
tree_predictions = tree.predict(X_test)

score = accuracy_score(y_test, tree_predictions)
print("Accuracy: ", score)
# Out:
# 2499
# (2499, 18)
# Accuracy:  0.9268585131894485

# %% [markdown]
# 1) If you will be asked to choose a single feature for classification which one you will choose.
# Justify with analysis.

# %% [markdown]
# I would choose "Total day minutes." The justification for this choice is based on the following analysis:
# - **Correlation Analysis**: The correlation matrix shows that "Total day minutes" has a high correlation with the "Churn" variable, indicating a strong relationship.
# - **Descriptive Statistics**: By examining the descriptive statistics for churned and non-churned customers, it is evident that churned customers have significantly higher average "Total day minutes."
# - **Feature Importance**: In preliminary machine learning models, "Total day minutes" consistently appears as one of the top features in terms of importance, indicating its predictive power.

# %% [markdown]
# 2) If you will be asked to choose two features for classification which two you will choose.
# Justify with analysis.

# %% [markdown]
# I would choose "Total day minutes" and "Customer service calls." The justification for these choices is based on the following analysis:
# - **Correlation Analysis**: Both features have strong correlations with the "Churn" variable, with "Total day minutes" showing the highest correlation and "Customer service calls" also showing a notable correlation.
# - **Descriptive Statistics**: "Total day minutes" is higher on average for churned customers, while "Customer service calls" is also higher for churned customers. This suggests that customers who make frequent calls to customer service are more likely to churn.
# - **Feature Combination**: The combination of "Total day minutes" and "Customer service calls" provides complementary information. "Total day minutes" captures usage patterns, while "Customer service calls" reflects customer dissatisfaction or issues, both of which are important factors in predicting churn.
# - **Feature Importance**: In preliminary machine learning models, these two features consistently appear among the top in terms of importance, indicating their combined predictive power.
